# %% [markdown]
# ### Introduction to Functions in Python
# In this video, we will discuss the most important module in Python, which is called functions. The outline includes what functions are, why we require them, how to define and call them, their syntax, parameters, default parameters, variable length arguments, positional and keyword arguments, and the return statement. Each concept will be demonstrated with code examples in Python.
#
# #### What is a Function?
# A function is a block of code that performs a specific task. Functions help in organizing code, reusing code, and improving readability. It is not necessary for a function to always return a value, but many functions do.
#
# #### Syntax of a Function
# A function starts with the def keyword, followed by the function name and any parameters. Optionally, a docstring can be included to describe what the function does. The function body contains the code, and finally, a return statement may be used to return a value.

# %%
def my_function():
    """This is a docstring."""
    # function body
    return

# %% [markdown]
# #### Why Do We Require Functions?
# Suppose you need to check whether a number is even or odd in multiple places in your project. Instead of copying the same code everywhere, you can write it once inside a function and reuse it.

# %%
num = 24
if num % 2 == 0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# The number is even

# %% [markdown]
# #### Defining and Calling a Function
# You can encapsulate the above logic in a function and call it wherever needed.

# %%
def even_or_odd(num):
    """This function finds whether a number is even or odd."""
    if num % 2 == 0:
        print("The number is even")
    else:
        print("The number is odd")

# %%
even_or_odd(24)
# Out:
# The number is even

# %% [markdown]
# #### Importance of Indentation
# Always ensure the indentation is correct in Python. If indentation is missing, you will get an error such as 'expected an indented block after the if statement.'
#
# #### Functions with Multiple Parameters
# Functions can accept multiple parameters of any type. For example, to add two numbers:

# %%
def add(a, b):
    return a + b

# %%
result = add(2, 4)
print(result)
# Out:
# 6

# %% [markdown]
# #### Default Parameters
# You can provide default values to function parameters. If the argument is not provided during the function call, the default value is used.

# %%
def greet(name="guest"):
    print(f"Hello {name}. Welcome to the Paradise.")

# %%
greet("Krish")
greet()
# Out:
# Hello Krish. Welcome to the Paradise.
# Hello guest. Welcome to the Paradise.

# %% [markdown]
# #### Variable Length Arguments
# Functions can accept a variable number of arguments using *args for positional arguments and **kwargs for keyword arguments.

# %%
def print_numbers(*args):
    for number in args:
        print(number)

# %%
print_numbers(1, 2, 3, 4, 5, 6, "crush")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# crush

# %% [markdown]
# #### Keyword Arguments
# Keyword arguments are provided as key-value pairs and are accessed using **kwargs.

# %%
def print_detail(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

# %%
print_detail(name="Krish", age=32, country="India")
# Out:
# name: Krish
# age: 32
# country: India

# %% [markdown]
# #### Combining Positional and Keyword Arguments
# You can combine both *args and **kwargs in a single function. Positional arguments must come before keyword arguments.

# %%
def print_detail(*args, **kwargs):
    print("Positional arguments:")
    for val in args:
        print(val)
    print("Keyword arguments:")
    for key, value in kwargs.items():
        print(f"{key}: {value}")

# %%
print_detail(1, 2, 3, 4, 5, name="Krish", age=32)
# Out:
# Positional arguments:
# 1
# 2
# 3
# 4
# 5
# Keyword arguments:
# name: Krish
# age: 32

# %% [markdown]
# #### The Return Statement
# The return statement is used to return values from a function. Functions can return single or multiple values.

# %%
def multiply(a, b):
    return a * b

# %%
result = multiply(2, 3)
print(result)
# Out:
# 6

# %% [markdown]
# #### Returning Multiple Values
# A function in Python can also return multiple values, which are returned as a tuple.

# %%
def multi_return(a, b):
    return a, b, a * b

# %%
x, y, prod = multi_return(2, 3)
print(x, y, prod)
# Out:
# 2 3 6

# %% [markdown]
# #### Conclusion
# This session covered the basics of functions in Python, including their syntax, parameters, default parameters, variable length arguments, positional and keyword arguments, and the return statement. In upcoming sessions, more advanced topics such as lambda functions, nested functions, and higher-order functions will be discussed.
#
# #### Key Takeaways
# Functions are essential for organizing, reusing, and improving the readability of code in Python.
# Functions can accept parameters, including default, positional, and keyword arguments, and can return single or multiple values.
# Variable length arguments in functions are handled using *args for positional arguments and **kwargs for keyword arguments.
# Proper use of indentation and docstrings is crucial for function clarity and error-free execution.
