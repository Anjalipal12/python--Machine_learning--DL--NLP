# %% [markdown]
# ### Exception Handling With try except else and finally blocks
# #### Introduction to Exception Handling in Python
# Exception handling in Python allows for graceful management of errors and enables corrective actions without stopping the execution of the program. In this lesson, we will cover the use of try, except, else, and finally blocks to handle exceptions effectively.
#
# #### What Are Exceptions?
# Exceptions are events that disrupt the normal flow of a program. They occur when an error is encountered during program execution. Common exceptions include ZeroDivisionError, FileNotFoundError, ValueError, TypeError, and NameError.
#
# #### Handling Exceptions with try and except
# To handle exceptions, Python provides the try and except blocks. The try block contains code that may raise an exception, while the except block handles the exception if it occurs.

# %%
a = 10

# %%
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a = b
#
# NameError: name 'b' is not defined

# %% [markdown]
# #### Example: Handling NameError
# If a variable is not defined, a NameError exception is raised. This can be handled using a try-except block to provide a user-friendly message.

# %%
try:
    a = b
except:
    print("The variable has not been assigned.")
# Out:
# The variable has not been assigned.

# %% [markdown]
# #### Catching Specific Exceptions
# You can catch specific exceptions by naming them in the except block. For example, to catch a NameError and display the error message:

# %%
try:
    a = b
except NameError as x:
    print(x)
# Out:
# name 'b' is not defined

# %% [markdown]
# #### Handling ZeroDivisionError
# Another common exception is ZeroDivisionError, which occurs when dividing by zero. This can be handled as follows:

# %%
try:
    result = 1 / 0
except ZeroDivisionError as x:
    print(x)
    print("Please enter the denominator greater than zero.")
# Out:
# division by zero
# Please enter the denominator greater than zero.

# %% [markdown]
# ### The Exception Base Class
# All exceptions like ZeroDivisionError, NameError, and ValueError are derived from the Exception base class. If you are unsure which exception may occur, you can catch all exceptions using Exception as follows:

# %%
try:
    a = b
except Exception as x1:
    print(x1)
# Out:
# name 'b' is not defined

# %% [markdown]
# #### Handling Multiple Exceptions
# You can handle multiple exceptions by writing multiple except blocks. For example, when taking user input and dividing by that number:

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ValueError:
    print("Not a valid number.")
except ZeroDivisionError:
    print("Enter denominator greater than zero.")
except Exception as x:
    print(x)
# Out:
# Not a valid number.

# %% [markdown]
# ### Using else with try-except
# The else block executes if no exception is raised in the try block. This is useful for code that should only run if the try block succeeds.

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ValueError:
    print("Not a valid number.")
except ZeroDivisionError:
    print("You can't divide the number by zero.")
except Exception as x:
    print(x)
else:
    print(f"The result is {result}")
# Out:
# You can't divide the number by zero.

# %% [markdown]
# ### Using finally with try-except
# The finally block is executed no matter what, whether an exception occurs or not. This is useful for cleanup actions, such as closing files or database connections.

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ValueError:
    print("Not a valid number.")
except ZeroDivisionError:
    print("You can't divide the number by zero.")
except Exception as x:
    print(x)
else:
    print(f"The result is {result}")
finally:
    print("Execution complete.")
# Out:
# The result is 5.0
# Execution complete.

# %% [markdown]
# ### Practical Example: File Handling with Exception Handling
# File operations are a common area where exceptions can occur. For example, attempting to open a file that does not exist will raise a FileNotFoundError. We can handle this as follows:

# %%
try:
    file = open("example1.txt", "r")
    content = file.read()
    print(content)
except FileNotFoundError:
    print("The file does not exist.")
finally:
    if 'file' in locals() and not file.closed:
        file.close()
        print("File closed.")
# Out:
# The file does not exist.

# %% [markdown]
# #### Conclusion
# Exception handling in Python using try, except, else, and finally blocks allows for robust and user-friendly programs. By handling exceptions gracefully, you can ensure that your programs do not crash unexpectedly and provide meaningful feedback to users.
#
# #### Key Takeaways
# Exception handling in Python allows for graceful error management using try, except, else, and finally blocks.
# Specific exceptions like NameError, ZeroDivisionError, and FileNotFoundError can be caught and handled with custom messages.
# The Exception class serves as the parent class for all exceptions, enabling the handling of any error type.
# The finally block ensures that cleanup actions, such as closing files or database connections, are executed regardless of exceptions.
