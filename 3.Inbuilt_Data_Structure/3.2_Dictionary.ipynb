# %% [markdown]
# #### What are Dictionaries?
# Dictionaries are unordered collections of items that store data in key-value pairs. All data is stored in key-value pairs. Keys must be unique and immutable. Once you define a key, it cannot be changed. Values can be changed, but keys must always be unique. Keys can include strings, numbers, or tuples, while values can be of any type.

# %% [markdown]
# #### Creating Dictionaries
# To create an empty dictionary, use curly braces {} or the dict() class.

# %%
empty_dict = {}
print(type(empty_dict))

empty_dict2 = dict()
print(type(empty_dict2))
# Out:
# <class 'dict'>
# <class 'dict'>

# %% [markdown]
# To create a dictionary with key-value pairs, use curly braces and separate keys and values with colons

# %%
student = {
    'name': 'Chris',
    'age': 32,
    'grade': 'A'
}
print(student)
print(type(student))
# Out:
# {'name': 'Chris', 'age': 32, 'grade': 'A'}
# <class 'dict'>

# %% [markdown]
# Accessing Dictionary Elements
# You can access dictionary values by using their keys or the .get() method.

# %%
student = {'name': 'Chris', 'age': 32, 'grade': 'A'}
print(student['grade'])
print(student['age'])
# Out:
# A
# 32

# %% [markdown]
# You can also use the get method to access values. If the key does not exist, it returns None or a default value if provided.

# %%
print(student.get('grade'))
print(student.get('last_name'))
print(student.get('last_name', 'Not Available'))
# Out:
# A
# None
# Not Available

# %% [markdown]
# #### Modifying Dictionary Elements
# Dictionaries are mutable. You can add, update, or delete elements. Keys must remain unique.

# %%
student['age'] = 33
student['address'] = 'India'
print(student)
# Out:
# {'name': 'Chris', 'age': 33, 'grade': 'A', 'address': 'India'}

# %% [markdown]
# To delete a key-value pair, use the del keyword.

# %%
del student['grade']
print(student)
# Out:
# {'name': 'Chris', 'age': 33, 'address': 'India'}

# %% [markdown]
# #### Common Dictionary Methods
# .keys() returns all keys.
# .values() returns all values.
# .items() returns all key-value pairs as tuples.

# %%
keys = student.keys()
print(keys)
values = student.values()
print(values)
items = student.items()
print(items)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['Chris', 33, 'India'])
# dict_items([('name', 'Chris'), ('age', 33), ('address', 'India')])

# %% [markdown]
# #### Shallow Copy of Dictionaries
# Assigning a dictionary to another variable creates a reference, not a copy. To create a shallow copy, use the .copy() method.

# %%
student_copy = student
print(student)
print(student_copy)
student['name'] = 'Chris2'
print(student)
print(student_copy)
# Out:
# {'name': 'Chris', 'age': 33, 'address': 'India'}
# {'name': 'Chris', 'age': 33, 'address': 'India'}
# {'name': 'Chris2', 'age': 33, 'address': 'India'}
# {'name': 'Chris2', 'age': 33, 'address': 'India'}

# %% [markdown]
# To avoid this, use the copy() method to create a true shallow copy.

# %%
student_copy1 = student.copy()
print(student_copy1)
student['name'] = 'Chris3'
print(student)
print(student_copy1)
# Out:
# {'name': 'Chris2', 'age': 33, 'address': 'India'}
# {'name': 'Chris3', 'age': 33, 'address': 'India'}
# {'name': 'Chris2', 'age': 33, 'address': 'India'}

# %% [markdown]
# Iterating Over Dictionaries
# You can use loops to iterate over keys, values, or items (key-value pairs) in a dictionary.

# %%
for key in student.keys():
    print(key)
for value in student.values():
    print(value)
for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# name
# age
# address
# Chris3
# 33
# India
# name: Chris3
# age: 33
# address: India

# %% [markdown]
# #### Nested Dictionaries
# A nested dictionary is a dictionary inside another dictionary. This is common in databases like MongoDB or Cassandra, where data is stored in key-value pairs.

# %%
students = {
    'student1': {'name': 'Chris', 'age': 32},
    'student2': {'name': 'Peter', 'age': 35}
}
print(students)
# Out:
# {'student1': {'name': 'Chris', 'age': 32}, 'student2': {'name': 'Peter', 'age': 35}}

# %% [markdown]
# To access elements in a nested dictionary, use multiple keys.

# %%
print(students['student2']['name'])
print(students['student2']['age'])
# Out:
# Peter
# 35

# %% [markdown]
# #### Iterating Over Nested Dictionaries
# You can iterate over nested dictionaries using loops and the .items() method.

# %%
for student_id, student_info in students.items():
    print(f"{student_id}: {student_info}")
    for key, value in student_info.items():
        print(f"{key}: {value}")
# Out:
# student1: {'name': 'Chris', 'age': 32}
# name: Chris
# age: 32
# student2: {'name': 'Peter', 'age': 35}
# name: Peter
# age: 35

# %% [markdown]
# #### Dictionary Comprehension
# Dictionary comprehension allows you to create dictionaries in a concise way, similar to list comprehensions.

# %%
squares = {x: x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %% [markdown]
# You can also add conditions in dictionary comprehensions.

# %%
evens = {x: x**2 for x in range(10) if x % 2 == 0}
print(evens)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %% [markdown]
# #### Practical Example: Counting Frequency of Elements in a List
# You can use a dictionary to count the frequency of elements in a list.

# %%
numbers = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
frequency = {}
for number in numbers:
    if number in frequency:
        frequency[number] += 1
    else:
        frequency[number] = 1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %% [markdown]
# #### Merging Two Dictionaries
# You can merge two dictionaries using the double asterisk ** operator.

# %%
dict1 = {'a': 1, 'b': 2}
dict2 = {'b': 3, 'c': 4}
merged_dict = {**dict1, **dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %% [markdown]
# #### Conclusion
# We have discussed dictionaries in Python, including their creation, access, modification, methods, iteration, nested dictionaries, comprehension, and practical examples. These concepts are essential for working with data in Python.
#
# #### Key Takeaways
# Dictionaries in Python are unordered collections that store data in key-value pairs, where keys must be unique and immutable.
# You can create, access, modify, and delete dictionary elements using various methods and operations.
# Dictionaries support methods like .keys(), .values(), .items(), and can be iterated over using loops.
# Nested dictionaries and dictionary comprehensions provide powerful ways to structure and generate data.
